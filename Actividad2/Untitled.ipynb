# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv('allende.txt', skiprows=4, sep='\s+')

# %%
df0.head()
# Out:
#    DD/MM/AAAA  HH:MM  DIRS  DIRR  VELS  VELR  TEMP    HR     PB  PREC  RAD-SOL
# 0  28/01/2019  20:00   288   300  0.53   2.2  22.8  16.0  815.1   0.0    786.7
# 1  28/01/2019  21:00   251   259  0.27   2.2  23.3  16.0  814.4   0.0    638.0
# 2  28/01/2019  22:00   281   243  0.27   2.2  23.7  15.0  814.0   0.0    441.0
# 3  28/01/2019  23:00     0   243  0.00   0.0  23.2  16.0  814.0   0.0    202.5
# 4  29/01/2019  00:00     0   243  0.00   0.0  20.5  16.0  814.5   0.0     19.5

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5cc0934cc03c> in <module>
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame(df0)

# %%
df.dtypes
# Out:
# DD/MM/AAAA     object
# HH:MM          object
# DIRS            int64
# DIRR            int64
# VELS          float64
# VELR          float64
# TEMP          float64
# HR            float64
# PB            float64
# PREC          float64
# RAD-SOL       float64
# dtype: object

# %%
df['FECHA'] = pd.to_datetime(df.apply(lambda x: x['DD/MM/AAAA'] + ' ' + x['HH:MM'], 1), dayfirst=True)
df = df.drop(['DD/MM/AAAA', 'HH:MM'], 1)

# %%
df.head()
# Out:
#    DIRS  DIRR  VELS  VELR  TEMP    HR     PB  PREC  RAD-SOL  \
# 0   288   300  0.53   2.2  22.8  16.0  815.1   0.0    786.7
# 1   251   259  0.27   2.2  23.3  16.0  814.4   0.0    638.0
# 2   281   243  0.27   2.2  23.7  15.0  814.0   0.0    441.0
# 3     0   243  0.00   0.0  23.2  16.0  814.0   0.0    202.5
# 4     0   243  0.00   0.0  20.5  16.0  814.5   0.0     19.5
#
#                 FECHA
# 0 2019-01-28 20:00:00
# 1 2019-01-28 21:00:00
# 2 2019-01-28 22:00:00
# 3 2019-01-28 23:00:00
# 4 2019-01-29 00:00:00

# %%
df.describe()
# Out:
#              DIRS        DIRR       VELS       VELR       TEMP          HR  \
# count   85.000000   85.000000  85.000000  85.000000  85.000000   85.000000
# mean    42.000000  231.858824   0.100471   0.507059  15.756471   47.710588
# std     92.000259   30.481123   0.272890   1.103866   8.056400   86.646246
# min      0.000000  173.000000   0.000000   0.000000   3.500000   15.000000
# 25%      0.000000  204.000000   0.000000   0.000000  11.300000   23.000000
# 50%      0.000000  238.000000   0.000000   0.000000  14.800000   35.000000
# 75%      0.000000  259.000000   0.000000   0.000000  20.600000   54.000000
# max    288.000000  300.000000   1.600000   5.600000  68.000000  818.400000
#
#                PB  PREC     RAD-SOL
# count   85.000000  85.0   84.000000
# mean   807.389412   0.0  228.447619
# std     88.629256   0.0  312.666354
# min      0.000000   0.0    0.000000
# 25%    815.900000   0.0    0.000000
# 50%    817.200000   0.0    0.000000
# 75%    817.900000   0.0  444.550000
# max    819.900000   0.0  865.500000

# %%
df_tmp = df[df.TEMP > 15] 
df_select = df_tmp[df_tmp.TEMP < 18]
df_select
# Out:
#     DIRS  DIRR  VELS  VELR  TEMP    HR     PB  PREC  RAD-SOL  \
# 5      0   243   0.0   0.0  16.5  24.0  815.0   0.0      0.0
# 6      0   243   0.0   0.0  15.7  30.0  815.9   0.0      0.0
# 22     0   189   0.0   0.0  17.9  34.0  817.8   0.0    830.7
# 29     0   238   0.0   0.0  17.3  34.0  814.7   0.0      0.0
# 30     0   238   0.0   0.0  15.2  45.0  815.4   0.0      0.0
# 31     0   238   0.0   0.0  16.9  34.0  816.2   0.0      0.0
# 53     0   269   0.0   0.0  17.7  27.0  815.7   0.0      0.0
# 54     0   269   0.0   0.0  16.2  27.0  816.3   0.0      0.0
# 55     0   269   0.0   0.0  16.1  27.0  817.2   0.0      0.0
# 67     0   269   0.0   0.0  15.4  35.0  819.5   0.0    410.7
# 68     0   269   0.0   0.0  17.1  31.0  819.8   0.0    623.7
# 78     0   204   0.0   0.0  16.4  38.0  817.4   0.0      0.0
# 79     0   204   0.0   0.0  15.2  39.0  818.1   0.0      0.0
#
#                  FECHA
# 5  2019-01-29 01:00:00
# 6  2019-01-29 02:00:00
# 22 2019-01-29 18:00:00
# 29 2019-01-30 01:00:00
# 30 2019-01-30 02:00:00
# 31 2019-01-30 03:00:00
# 53 2019-01-31 01:00:00
# 54 2019-01-31 02:00:00
# 55 2019-01-31 03:00:00
# 67 2019-01-31 15:00:00
# 68 2019-01-31 16:00:00
# 78 2019-02-01 02:00:00
# 79 2019-02-01 03:00:00

# %%
df.mean()
# Out:
# DIRS        42.000000
# DIRR       231.858824
# VELS         0.100471
# VELR         0.507059
# TEMP        15.756471
# HR          47.710588
# PB         807.389412
# PREC         0.000000
# RAD-SOL    228.447619
# dtype: float64

# %% [raw]
# df.TEMP.mean()

# %%
df1 = df[['TEMP']]
plt.figure(); df1.plot(); plt.legend(loc='best')
plt.title("TEMPERATURA ")
plt.grid(True)
plt.show()
